# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
db_uri = "mysql+pymysql://statsuser:statspass@localhost:3306/statsdb"
engine = create_engine(db_uri)

guery = """
SELECT *
FROM statistic
WHERE type = 'mediaSeen_PROGRAM';
"""

# %%
df = pd.read_sql(guery, engine)

# %%
df.drop_duplicates
df
# Out:
#                 id            cusRef                 devRef     devType  \
# 0      50582124767   185224001684602       1852240016846021  MOTOROLA_4
# 1      50582125023   960152002385458       9601520023854581  MOTOROLA_4
# 2      50582125170   964393002402191       9643930024021912  MOTOROLA_4
# 3      50582125274   990546002886325       9905460028863251    KREATV_5
# 4      50582125293   312341002207341       3123410022073411  MOTOROLA_4
# ...            ...               ...                    ...         ...
# 15076  50595720119   867641001423017       8676410014230171  MOTOROLA_4
# 15077  50595720987   121607002470267       1216070024702671  MOTOROLA_4
# 15078  50595720994  9999783500549999      99997835005499991       AMINO
# 15079  50595721243   275890001448446       2758900014484462  MOTOROLA_4
# 15080  50595721722  2000000000063067  200000000006306700001    KREATV_5
#
#       devModel   timeZone                                          cusGrRefs  \
# 0      VIP1113  UTC+01:00  ["100128","100131","1006","A0","C1","0","A2","...
# 1      VIP1113  UTC+02:00      ["100128","100131","1006","C1","0","V0","R1"]
# 2      VIP1113  UTC+02:00      ["100128","100131","1006","C1","0","V0","R1"]
# 3      VIP4205  UTC+01:00               ["100128","R1","1006","C1","0","V0"]
# 4      VIP1113  UTC+01:00                ["100128","100131","1006","C1","0"]
# ...        ...        ...                                                ...
# 15076  VIP1113  UTC+02:00  ["100128","100131","1006","A0","C1","0","A2","...
# 15077  VIP1113  UTC+01:00      ["100128","100131","1006","C1","0","V0","R1"]
# 15078     A139  UTC+02:00                              ["L1","L2","A0","A2"]
# 15079  VIP1113  UTC+02:00  ["100131","1006","A0","C1","0","10010","A1","A...
# 15080  VIP4205  UTC+02:00  ["S1","100128","100131","M1","M2","C1","0","M0...
#
#           ref               type                              name  \
# 0          33  mediaSeen_PROGRAM                       Kviz 1 na 1
# 1      100889  mediaSeen_PROGRAM                              Prva
# 2          29  mediaSeen_PROGRAM                        Prijatelji
# 3          28  mediaSeen_PROGRAM                      Divlje pčele
# 4      100865  mediaSeen_PROGRAM                    Kad lišće pada
# ...       ...                ...                               ...
# 15076     310  mediaSeen_PROGRAM                              Pink
# 15077     326  mediaSeen_PROGRAM                  Ponos Ratkajevih
# 15078      29  mediaSeen_PROGRAM            Teorija velikog praska
# 15079      29  mediaSeen_PROGRAM                     Teški zločini
# 15080     403  mediaSeen_PROGRAM  Preživljavanje - Goli i uplašeni
#
#                 time  duration  \
# 0      1776722132309     37885
# 1      1776722351496     17247
# 2      1776722364420     41883
# 3      1776722353676     23083
# 4      1776722352799     60044
# ...              ...       ...
# 15076  1776808765659     11314
# 15077  1776808555841     20180
# 15078  1776808609686     60034
# 15079  1776808651086     26023
# 15080  1776808759885     10601
#
#                                                    extra    deliveredTS  \
# 0      {"title":"Kviz 1 na 1","genre":"Zabava","start...  1776722394551
# 1      {"title":"Na mestu zločina sa Mašanom","genre"...  1776722397043
# 2      {"title":"Prijatelji","genre":"Film","startTim...  1776722398517
# 3      {"title":"Divlje pčele","genre":"Film","startT...  1776722399558
# 4      {"title":"Kad lišće pada","genre":"Film","star...  1776722399732
# ...                                                  ...            ...
# 15076  {"title":"Ami G Show","genre":"Zabava","startT...  1776808780386
# 15077  {"title":"Ponos Ratkajevih","genre":"Film","st...  1776808782501
# 15078  {"title":"Teorija velikog praska","genre":"Fil...  1776808782588
# 15079  {"title":"Teški zločini","genre":"Film","start...  1776808785937
# 15080  {"title":"Preživljavanje - Goli i uplašeni","g...  1776808791885
#
#                insertedTS
# 0     2026-04-21 00:00:00
# 1     2026-04-21 00:00:00
# 2     2026-04-21 00:00:00
# 3     2026-04-21 00:00:00
# 4     2026-04-21 00:00:00
# ...                   ...
# 15076 2026-04-21 23:59:51
# 15077 2026-04-21 23:59:54
# 15078 2026-04-21 23:59:54
# 15079 2026-04-21 23:59:54
# 15080 2026-04-21 23:59:54
#
# [15081 rows x 15 columns]

# %%
top_name = (
    df.groupby("name")
    .size()
    .reset_index(name="count")
    .sort_values(by="count", ascending=False)
)

top_name
# Out:
#                                   name  count
# 210                            Elita 9    664
# 311   Igra sudbine: Ljubav nakon greha    450
# 159                       Divlje pčele    424
# 620                         Pepa prase    380
# 977                         Zarobljena    354
# ...                                ...    ...
# 441                Ljubav na prvi ples      1
# 442             Ljubav, navika, panika      1
# 444                      Lopov s krova      1
# 448            Lovac i ledena kraljica      1
# 1009               Čitulja za Eskobara      1
#
# [1047 rows x 2 columns]
